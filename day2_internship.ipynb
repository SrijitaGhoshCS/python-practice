# %% [markdown]
# <a href="https://colab.research.google.com/github/SrijitaGhoshCS/python-practice/blob/main/day2_internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1: Semester Exam Hall-Ticket Screener
attendance_pct = 72
has_medical_certificate = True

if attendance_pct >= 75:
    print("Eligible for Regular Admit Card")
elif attendance_pct >= 65 and has_medical_certificate:
    print("Condoned: Eligible on Medical Grounds")
else:
    print("Debarred: Attendance Below Minimum Criteria")
# Out:
# Condoned: Eligible on Medical Grounds

# %%
#Task 2: One-Line Result Generator
cgpa = 8.2
division = "First Class with Distinction" if cgpa >= 8.0 else "Standard Pass"
print(f"Student Result: {division}")

# %%
#Task 3: Fix the Runaway Loop
upload_attempt=1
while upload_attempt<=4:
  print(f"Connecting to cloud server...attempt{upload_attempt}")
  upload_attempt+=1
# Out:
# Connecting to cloud server...attempt1
# Connecting to cloud server...attempt2
# Connecting to cloud server...attempt3
# Connecting to cloud server...attempt4

# %%
#Task 4: Sequence Index Printer
course_code = "AIML2026"
for i in range(len(course_code)):
    print(f"Index [{i}] -> {course_code[i]}")
# Out:
# Index [0] -> A
# Index [1] -> I
# Index [2] -> M
# Index [3] -> L
# Index [4] -> 2
# Index [5] -> 0
# Index [6] -> 2
# Index [7] -> 6

# %%
#Task 5: Dirty Data Sanitizer
raw_dept = " compuTER SCIENCE & eng "
cleaned_dept = raw_dept.strip().lower().replace("eng", "engineering")
print(cleaned_dept)
# Out:
# computer science & engineering

# %%
#Task 6: Roll Number Slicer & Membership Validator
student_id = "WPC-CSE-2026-088"
print(student_id[4:7])
print("2026" in student_id)
print(student_id[::-1])
# Out:
# CSE
# True
# 880-6202-ESC-CPW
