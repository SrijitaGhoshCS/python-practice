# %% [markdown]
# <a href="https://colab.research.google.com/github/SrijitaGhoshCS/python-practice/blob/main/Another_copy_of_Untitled28.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Task 1:Variables and Bill calculations
samosa_price=15
samosa_qty=3
tea_price=10
tea_qty=2
total_bill=samosa_price*samosa_qty+tea_price*tea_qty
print(f"Total Bill=RS{total_bill}")
# Out:
# Total Bill=RS65

# %%
#Task 2:LAttendance Percentage Calculator
total_classes = 80
attended_classes = 66
attendance_percentage = (attended_classes / total_classes) * 100
print(f"Attendance Percentage: {attendance_percentage:.1f}")
# Out:
# Attendance Percentage: 82.5

# %%
#Task 3:The Bug Hunt(Fix the String Trap)
sub1_marks = "45"
sub2_marks = "48"
total = int(sub1_marks) + int(sub2_marks)
print(f"Total Marks: {total}")
# Out:
# Total Marks: 93

# %%
#Task 4:Dynamic User Age Projector
birth_year = "2006"
current_year = 2026
birth_year = int(birth_year)
age = current_year - birth_year
print(f"Age in {current_year}: {age}")
# Out:
# Age in 2026: 20

# %%
#Task 5:Digital College ID Card Generator
student_name = "Srijita"
dept = "Computer Science"
roll_no = 25
cgpa = 8.5
is_eligible = True
print("=" * 30)
print(f"Student Name : {student_name}")
print(f"Department   : {dept}")
print(f"Roll Number  : {roll_no}")
print(f"CGPA         : {cgpa}")
print(f"Eligible     : {is_eligible}")
print("=" * 30)
# Out:
# ...
# Student Name : Srijita
# Department   : Computer Science
# Roll Number  : 25
# CGPA         : 8.5
# Eligible     : True
# ...

# %%
#Task 6: Split the Project Expense
team_members = 4
total_cost = 1250
each_student_pays = total_cost // team_members
remaining_amount = total_cost % team_members
print(f"Each student pays: {each_student_pays}")
print(f"Remaining amount: {remaining_amount}")
# Out:
# Each student pays: 312
# Remaining amount: 2
